# %% [markdown]
# # Analysing FEMA's National Flood Insurance Program (NFIP) Data Using Python

# %%
# importing libraries
import pandas as pd # the pd is by convention
import numpy as np # as is the np
import geopandas as gpd
from geopandas.tools import overlay
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pylab as pl 
import shapely
from fiona.crs import from_epsg
import urllib
from matplotlib.ticker import FuncFormatter
import matplotlib.dates as mdates



# to Plot matplotlib figures inline on the notebook
# %matplotlib inline

# %%
# changing directories to Downloads folder
# %cd ~/Downloads/
# Out:
# /Users/geribauer/Downloads

# %%
# dowloading the data with urllib.request.urlretrieve()
url = 'https://www.fema.gov/media-library-data/1575491579309-2366ee38d902c1bc983370e132ee36cc/FIMA_NFIP_Redacted_Claims_Data_Set.zip'

# retrieving the file and naming it as 'nfip_claims.gz'
urllib.request.urlretrieve(url, "nfip_claims_year.gz")
# Out:
# ('nfip_claims_year.gz', <http.client.HTTPMessage at 0x1a19f92438>)

# %%
# unzipping the file
# !unzip -d ~/Downloads/ nfip_claims_year.gz
# Out:
# Archive:  nfip_claims_year.gz
#   inflating: /Users/geribauer/Downloads/NFIP Claims Instructions and Metadata.xlsx
#   inflating: /Users/geribauer/Downloads/openFEMA_claims20190831.csv

# %%
# moving the metadata into our nyc project data folder
# %mv 'NFIP Claims Instructions and Metadata.xlsx' ~/'fema-nfip-claims/nfip-claims-national/data-dictionary/NFIP-claims-instructions-and-metadata.xlsx'

# %%
# %cd ~/'fema-nfip-claims/nfip-claims-national/data-dictionary'
# %ls
# Out:
# /Users/geribauer/fema-nfip-claims/nfip-claims-national/data-dictionary
# NFIP-claims-instructions-and-metadata.xlsx*

# %%
# changing directories to Downloads folder
# %cd ~/Downloads/
# Out:
# /Users/geribauer/Downloads

# %%
# read our data into a DataFrame
nfip_claims = pd.read_csv('openFEMA_claims20190831.csv')
# Out:
# /Users/geribauer/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,11,15,22,23,31,32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nfip_claims.head()
# Out:
#   agriculturestructureindicator    asofdate  basefloodelevation  \
# 0                           NaN  2019-08-31                 NaN
# 1                           NaN  2019-08-31                 NaN
# 2                           NaN  2019-08-31                 NaN
# 3                           NaN  2019-08-31                 NaN
# 4                           NaN  2019-08-31                 NaN
#
#    basementenclosurecrawlspacetype reportedcity condominiumindicator  \
# 0                              0.0    OCEANSIDE                    N
# 1                              0.0  NEW ORLEANS                    N
# 2                              0.0      NAVARRE                    N
# 3                              1.0     BEAUFORT                    N
# 4                              0.0    MELBOURNE                    N
#
#    policycount  countycode  crsdiscount  dateofloss        ...         \
# 0          1.0      6073.0         0.00  1998-02-07        ...
# 1          1.0     22071.0         0.00  2005-08-29        ...
# 2          1.0     12113.0         0.05  1998-09-28        ...
# 3          1.0     45013.0         0.00  1994-10-07        ...
# 4          1.0     12009.0         0.00  1996-03-11        ...
#
#   amountpaidonincreasedcostofcomplianceclaim postfirmconstructionindicator  \
# 0                                        NaN                             N
# 1                                        NaN                             N
# 2                                        0.0                             N
# 3                                        NaN                             N
# 4                                        NaN                             Y
#
#    ratemethod  smallbusinessindicatorbuilding state  \
# 0           7                             NaN    CA
# 1           7                             NaN    LA
# 2           1                             NaN    FL
# 3           7                             NaN    SC
# 4           7                             NaN    FL
#
#   totalbuildinginsurancecoverage  totalcontentsinsurancecoverage yearofloss  \
# 0                       200000.0                         50000.0       1998
# 1                       100000.0                         40000.0       2005
# 2                       100000.0                         50000.0       1998
# 3                       100000.0                         25000.0       1994
# 4                       100000.0                         25000.0       1996
#
#    reportedzipcode  primaryresidence
# 0            92056               NaN
# 1            70131                 Y
# 2            32566               NaN
# 3            29902               NaN
# 4            32940               NaN
#
# [5 rows x 39 columns]

# %%
print('This dataset is as of', nfip_claims.asofdate[0], "from FEMA's Open Data Portal.")
# Out:
# This dataset is as of 2019-08-31 from FEMA's Open Data Portal.

# %%
# %cd ~/fema-nfip-claims/nfip-claims-national
# Out:
# /Users/geribauer/fema-nfip-claims/nfip-claims-national

# %%
nfip_claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2432888 entries, 0 to 2432887
# Data columns (total 39 columns):
# agriculturestructureindicator                 object
# asofdate                                      object
# basefloodelevation                            float64
# basementenclosurecrawlspacetype               float64
# reportedcity                                  object
# condominiumindicator                          object
# policycount                                   float64
# countycode                                    float64
# crsdiscount                                   float64
# dateofloss                                    object
# elevatedbuildingindicator                     object
# elevationcertificateindicator                 object
# elevationdifference                           float64
# censustract                                   float64
# floodzone                                     object
# houseworship                                  object
# latitude                                      float64
# locationofcontents                            object
# longitude                                     float64
# lowestadjacentgrade                           float64
# lowestfloorelevation                          float64
# numberoffloorsintheinsuredbuilding            float64
# nonprofitindicator                            object
# obstructiontype                               object
# occupancytype                                 float64
# originalconstructiondate                      object
# originalnbdate                                object
# amountpaidonbuildingclaim                     float64
# amountpaidoncontentsclaim                     float64
# amountpaidonincreasedcostofcomplianceclaim    float64
# postfirmconstructionindicator                 object
# ratemethod                                    object
# smallbusinessindicatorbuilding                object
# state                                         object
# totalbuildinginsurancecoverage                float64
# totalcontentsinsurancecoverage                float64
# yearofloss                                    int64
# reportedzipcode                               object
# primaryresidence                              object
# dtypes: float64(18), int64(1), object(20)
# memory usage: 723.9+ MB

# %%
nfip_claims.describe()
# Out:
#        basefloodelevation  basementenclosurecrawlspacetype   policycount  \
# count       483589.000000                     2.432843e+06  2.432880e+06
# mean            71.378912                     4.672303e-01  1.247610e+00
# std            300.583343                     9.312251e-01  6.239860e+00
# min          -6002.000000                     0.000000e+00  1.000000e+00
# 25%              7.000000                     0.000000e+00  1.000000e+00
# 50%              9.000000                     0.000000e+00  1.000000e+00
# 75%             14.000000                     0.000000e+00  1.000000e+00
# max           9998.000000                     4.000000e+00  1.090000e+03
#
#          countycode   crsdiscount  elevationdifference   censustract  \
# count  2.425385e+06  2.432880e+06         2.432880e+06  2.373588e+06
# mean   3.020189e+04  3.494819e-02         7.505239e+02  3.004539e+10
# std    1.456152e+04  6.239606e-02         4.321235e+02  1.445356e+10
# min    1.001000e+03  0.000000e+00        -1.987000e+03  1.003000e+03
# 25%    2.201900e+04  0.000000e+00         9.990000e+02  2.201900e+10
# 50%    2.916300e+04  0.000000e+00         9.990000e+02  2.912796e+10
# 75%    4.207500e+04  5.000000e-02         9.990000e+02  4.206195e+10
# max    7.803000e+04  4.000000e-01         9.998000e+03  7.803096e+10
#
#            latitude     longitude  lowestadjacentgrade  lowestfloorelevation  \
# count  2.379340e+06  2.379340e+06        350723.000000         475071.000000
# mean   3.404449e+01 -8.614260e+01            75.457087            148.298637
# std    5.801293e+00  1.111013e+01           546.574281            980.141421
# min   -1.430000e+01 -1.707000e+02         -3411.000000          -6002.000000
# 25%    2.990000e+01 -9.140000e+01             3.200000              6.500000
# 50%    3.190000e+01 -8.750000e+01             6.700000             10.300000
# 75%    3.990000e+01 -7.690000e+01            12.900000             17.800000
# max    6.990000e+01  1.449000e+02         99999.100000          99999.900000
#
#        numberoffloorsintheinsuredbuilding  occupancytype  \
# count                        2.416237e+06   2.432168e+06
# mean                         1.722882e+00   1.404049e+00
# std                          8.858817e-01   9.672842e-01
# min                          1.000000e+00   1.000000e+00
# 25%                          1.000000e+00   1.000000e+00
# 50%                          1.000000e+00   1.000000e+00
# 75%                          2.000000e+00   1.000000e+00
# max                          6.000000e+00   6.000000e+00
#
#        amountpaidonbuildingclaim  amountpaidoncontentsclaim  \
# count               2.359510e+06               1.712987e+06
# mean                2.367499e+04               7.729023e+03
# std                 5.278161e+04               2.280169e+04
# min                -2.920705e+04              -8.484000e+03
# 25%                 1.085800e+02               0.000000e+00
# 50%                 4.818810e+03               2.290000e+02
# 75%                 2.402774e+04               5.830405e+03
# max                 1.000000e+07               7.500000e+05
#
#        amountpaidonincreasedcostofcomplianceclaim  \
# count                                1.160371e+06
# mean                                 7.600233e+02
# std                                  4.441656e+03
# min                                  0.000000e+00
# 25%                                  0.000000e+00
# 50%                                  0.000000e+00
# 75%                                  0.000000e+00
# max                                  6.000000e+04
#
#        totalbuildinginsurancecoverage  totalcontentsinsurancecoverage  \
# count                    2.432880e+06                    2.432880e+06
# mean                     1.512794e+05                    2.819080e+04
# std                      2.777121e+06                    4.809394e+04
# min                      0.000000e+00                    0.000000e+00
# 25%                      3.500000e+04                    0.000000e+00
# 50%                      9.080000e+04                    1.050000e+04
# 75%                      1.950000e+05                    4.000000e+04
# max                      4.000000e+09                    6.000000e+06
#
#          yearofloss
# count  2.432888e+06
# mean   2.000633e+03
# std    1.179710e+01
# min    1.970000e+03
# 25%    1.992000e+03
# 50%    2.004000e+03
# 75%    2.011000e+03
# max    2.019000e+03

# %%
nfip_claims.iloc[:,:15].head()
# Out:
#   agriculturestructureindicator    asofdate  basefloodelevation  \
# 0                           NaN  2019-08-31                 NaN
# 1                           NaN  2019-08-31                 NaN
# 2                           NaN  2019-08-31                 NaN
# 3                           NaN  2019-08-31                 NaN
# 4                           NaN  2019-08-31                 NaN
#
#    basementenclosurecrawlspacetype reportedcity condominiumindicator  \
# 0                              0.0    OCEANSIDE                    N
# 1                              0.0  NEW ORLEANS                    N
# 2                              0.0      NAVARRE                    N
# 3                              1.0     BEAUFORT                    N
# 4                              0.0    MELBOURNE                    N
#
#    policycount  countycode  crsdiscount  dateofloss elevatedbuildingindicator  \
# 0          1.0      6073.0         0.00  1998-02-07                         N
# 1          1.0     22071.0         0.00  2005-08-29                         N
# 2          1.0     12113.0         0.05  1998-09-28                         N
# 3          1.0     45013.0         0.00  1994-10-07                         N
# 4          1.0     12009.0         0.00  1996-03-11                         N
#
#   elevationcertificateindicator  elevationdifference   censustract floodzone
# 0                           NaN                999.0  6.073019e+09         X
# 1                           NaN                999.0  2.207100e+10         X
# 2                           NaN                999.0  1.211301e+10         X
# 3                           NaN                999.0  4.501300e+10         X
# 4                           NaN                999.0  1.200906e+10         X

# %%
nfip_claims.iloc[:,15:30].head()
# Out:
#   houseworship  latitude locationofcontents  longitude  lowestadjacentgrade  \
# 0          NaN      33.2                NaN     -117.3                  NaN
# 1          NaN      29.9                NaN      -90.0                  NaN
# 2          NaN      30.4                NaN      -86.9                  NaN
# 3          NaN      32.4                NaN      -80.7                  NaN
# 4          NaN      28.3                NaN      -80.7                  NaN
#
#    lowestfloorelevation  numberoffloorsintheinsuredbuilding  \
# 0                   NaN                                 4.0
# 1                   NaN                                 2.0
# 2                   NaN                                 1.0
# 3                   NaN                                 2.0
# 4                   NaN                                 1.0
#
#   nonprofitindicator obstructiontype  occupancytype originalconstructiondate  \
# 0                NaN              10            1.0               1963-01-01
# 1                NaN              10            1.0               1967-07-01
# 2                NaN              10            1.0               1972-01-01
# 3                NaN              10            1.0               1960-01-01
# 4                NaN              10            1.0               1988-01-01
#
#   originalnbdate  amountpaidonbuildingclaim  amountpaidoncontentsclaim  \
# 0     1997-01-11                       0.00                        0.0
# 1     1990-07-12                       0.00                        0.0
# 2     1997-07-24                    8813.21                     1720.0
# 3     1993-10-01                    2906.00                        0.0
# 4     1996-01-11                    3875.53                     1545.0
#
#    amountpaidonincreasedcostofcomplianceclaim
# 0                                         NaN
# 1                                         NaN
# 2                                         0.0
# 3                                         NaN
# 4                                         NaN

# %%
nfip_claims.iloc[:,30:].head()
# Out:
#   postfirmconstructionindicator ratemethod smallbusinessindicatorbuilding  \
# 0                             N          7                            NaN
# 1                             N          7                            NaN
# 2                             N          1                            NaN
# 3                             N          7                            NaN
# 4                             Y          7                            NaN
#
#   state  totalbuildinginsurancecoverage  totalcontentsinsurancecoverage  \
# 0    CA                        200000.0                         50000.0
# 1    LA                        100000.0                         40000.0
# 2    FL                        100000.0                         50000.0
# 3    SC                        100000.0                         25000.0
# 4    FL                        100000.0                         25000.0
#
#    yearofloss reportedzipcode primaryresidence
# 0        1998           92056              NaN
# 1        2005           70131                Y
# 2        1998           32566              NaN
# 3        1994           29902              NaN
# 4        1996           32940              NaN

# %%
# adding a new column called 'amountpaidontotalclaim' that adds both building and contents claim to get the total claim

nfip_claims['amountpaidontotalclaim'] = nfip_claims['amountpaidonbuildingclaim'] + nfip_claims['amountpaidoncontentsclaim']

# %%
nfip_claims[['amountpaidonbuildingclaim', 'amountpaidoncontentsclaim', 'amountpaidontotalclaim']].head()
# Out:
#    amountpaidonbuildingclaim  amountpaidoncontentsclaim  \
# 0                       0.00                        0.0
# 1                       0.00                        0.0
# 2                    8813.21                     1720.0
# 3                    2906.00                        0.0
# 4                    3875.53                     1545.0
#
#    amountpaidontotalclaim
# 0                    0.00
# 1                    0.00
# 2                10533.21
# 3                 2906.00
# 4                 5420.53

# %% [markdown]
# ## Group by Claim Count

# %%
# grouping dataframe by 'Year' and counting values of columns
nfip_claims_year_count = nfip_claims.groupby('yearofloss').count()

# %%
nfip_claims_year_count.head()
# Out:
#             agriculturestructureindicator  asofdate  basefloodelevation  \
# yearofloss
# 1970                                    0         1                   0
# 1972                                    0         1                   0
# 1973                                    0         9                   0
# 1974                                    0        13                   0
# 1975                                    0        45                   0
#
#             basementenclosurecrawlspacetype  reportedcity  \
# yearofloss
# 1970                                      1             1
# 1972                                      1             1
# 1973                                      9             9
# 1974                                     13            13
# 1975                                     45            45
#
#             condominiumindicator  policycount  countycode  crsdiscount  \
# yearofloss
# 1970                           0            1           0            1
# 1972                           0            1           0            1
# 1973                           0            9           6            9
# 1974                           0           13          10           13
# 1975                           0           45          38           45
#
#             dateofloss           ...            \
# yearofloss                       ...
# 1970                 1           ...
# 1972                 1           ...
# 1973                 9           ...
# 1974                13           ...
# 1975                45           ...
#
#             amountpaidonincreasedcostofcomplianceclaim  \
# yearofloss
# 1970                                                 0
# 1972                                                 0
# 1973                                                 0
# 1974                                                 0
# 1975                                                 0
#
#             postfirmconstructionindicator  ratemethod  \
# yearofloss
# 1970                                    0           0
# 1972                                    0           0
# 1973                                    0           0
# 1974                                    0           0
# 1975                                    0           0
#
#             smallbusinessindicatorbuilding  state  \
# yearofloss
# 1970                                     0      1
# 1972                                     0      1
# 1973                                     0      9
# 1974                                     0     13
# 1975                                     0     45
#
#             totalbuildinginsurancecoverage  totalcontentsinsurancecoverage  \
# yearofloss
# 1970                                     1                               1
# 1972                                     1                               1
# 1973                                     9                               9
# 1974                                    13                              13
# 1975                                    45                              45
#
#             reportedzipcode  primaryresidence  amountpaidontotalclaim
# yearofloss
# 1970                      1                 0                       0
# 1972                      1                 0                       0
# 1973                      9                 0                       4
# 1974                     13                 0                       5
# 1975                     45                 0                      25
#
# [5 rows x 39 columns]

# %%
nfip_claims_year_count[['asofdate']].head()
# Out:
#             asofdate
# yearofloss
# 1970               1
# 1972               1
# 1973               9
# 1974              13
# 1975              45

# %%
nfip_claims_year_count.rename(columns={"asofdate": "claimscount"}, inplace=True)

# %%
nfip_claims_year_count[['claimscount']].head()
# Out:
#             claimscount
# yearofloss
# 1970                  1
# 1972                  1
# 1973                  9
# 1974                 13
# 1975                 45

# %%
nfip_claims_year_count = nfip_claims_year_count[['claimscount']]

# %%
nfip_claims_year_count.head()
# Out:
#             claimscount
# yearofloss
# 1970                  1
# 1972                  1
# 1973                  9
# 1974                 13
# 1975                 45

# %%
nfip_claims_year_count.shape
# Out:
# (49, 1)

# %%
nfip_claims_year_count.claimscount.sum()
# Out:
# 2432888

# %% [markdown]
# ## Group by Claim Dollar Amount

# %%
nfip_claims_year_amount = nfip_claims.groupby('yearofloss').sum()

# %%
nfip_claims_year_amount.head()
# Out:
#             basefloodelevation  basementenclosurecrawlspacetype  policycount  \
# yearofloss
# 1970                       0.0                              1.0          1.0
# 1972                       0.0                              0.0          1.0
# 1973                       0.0                              8.0          9.0
# 1974                       0.0                             16.0         13.0
# 1975                       0.0                             90.0         45.0
#
#             countycode  crsdiscount  elevationdifference   censustract  \
# yearofloss
# 1970               0.0          0.0                999.0  0.000000e+00
# 1972               0.0          0.0                999.0  0.000000e+00
# 1973          129444.0          0.0               6993.0  1.294467e+11
# 1974          321774.0          0.0              11185.0  2.877715e+11
# 1975         1413103.0          0.0              38158.0  1.398103e+12
#
#             latitude  longitude  lowestadjacentgrade  lowestfloorelevation  \
# yearofloss
# 1970             0.0        0.0                  0.0                   0.0
# 1972             0.0        0.0                  0.0                   0.0
# 1973           223.6     -497.8                  0.0                   0.0
# 1974           333.2     -777.6                  0.0                   0.0
# 1975          1382.2    -3065.1                  0.0                  99.0
#
#             numberoffloorsintheinsuredbuilding  occupancytype  \
# yearofloss
# 1970                                       1.0            1.0
# 1972                                       1.0            1.0
# 1973                                      12.0           11.0
# 1974                                      21.0           17.0
# 1975                                      81.0           80.0
#
#             amountpaidonbuildingclaim  amountpaidoncontentsclaim  \
# yearofloss
# 1970                             0.00                       0.00
# 1972                             0.00                       0.00
# 1973                          9720.00                    3547.00
# 1974                         28908.00                    4707.78
# 1975                        128774.55                   99233.73
#
#             amountpaidonincreasedcostofcomplianceclaim  \
# yearofloss
# 1970                                               0.0
# 1972                                               0.0
# 1973                                               0.0
# 1974                                               0.0
# 1975                                               0.0
#
#             totalbuildinginsurancecoverage  totalcontentsinsurancecoverage  \
# yearofloss
# 1970                                   0.0                             0.0
# 1972                                   0.0                             0.0
# 1973                              101500.0                         19000.0
# 1974                              154500.0                         91500.0
# 1975                             1086000.0                        677800.0
#
#             amountpaidontotalclaim
# yearofloss
# 1970                          0.00
# 1972                          0.00
# 1973                      13267.00
# 1974                       3908.00
# 1975                      97611.73

# %%
nfip_claims_year_amount[['amountpaidontotalclaim']].head()
# Out:
#             amountpaidontotalclaim
# yearofloss
# 1970                          0.00
# 1972                          0.00
# 1973                      13267.00
# 1974                       3908.00
# 1975                      97611.73

# %%
nfip_claims_year_amount = nfip_claims_year_amount[['amountpaidontotalclaim']]

# %%
nfip_claims_year_amount.head()
# Out:
#             amountpaidontotalclaim
# yearofloss
# 1970                          0.00
# 1972                          0.00
# 1973                      13267.00
# 1974                       3908.00
# 1975                      97611.73

# %% [markdown]
# ## Join dataframes (i.e count and claim dollar amount)

# %%
nfip_claims_year_count.reset_index(inplace=True)
nfip_claims_year_count.head()
# Out:
#    yearofloss  claimscount
# 0        1970            1
# 1        1972            1
# 2        1973            9
# 3        1974           13
# 4        1975           45

# %%
nfip_claims_year_amount.reset_index(inplace=True)
nfip_claims_year_amount.head()
# Out:
#    yearofloss  amountpaidontotalclaim
# 0        1970                    0.00
# 1        1972                    0.00
# 2        1973                13267.00
# 3        1974                 3908.00
# 4        1975                97611.73

# %%
nfip_claims_year = nfip_claims_year_count.merge(nfip_claims_year_amount, left_on="yearofloss", 
              right_on="yearofloss")

# %%
nfip_claims_year.head()
# Out:
#    yearofloss  claimscount  amountpaidontotalclaim
# 0        1970            1                    0.00
# 1        1972            1                    0.00
# 2        1973            9                13267.00
# 3        1974           13                 3908.00
# 4        1975           45                97611.73

# %% [markdown]
# ## Formatting to create timeseries plot

# %%
# setting index to 'dateofloss' column
nfip_claims_year.set_index('yearofloss', drop=False, inplace=True)
nfip_claims_year.head()
# Out:
#             yearofloss  claimscount  amountpaidontotalclaim
# yearofloss
# 1970              1970            1                    0.00
# 1972              1972            1                    0.00
# 1973              1973            9                13267.00
# 1974              1974           13                 3908.00
# 1975              1975           45                97611.73

# %%
# transforming our 'Year' index to datetime
nfip_claims_year.index = pd.to_datetime(nfip_claims_year.index, format='%Y')

# %%
nfip_claims_year.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
nfip_claims_year.head()
# Out:
#             yearofloss  claimscount  amountpaidontotalclaim
# yearofloss
# 1970-01-01        1970            1                    0.00
# 1972-01-01        1972            1                    0.00
# 1973-01-01        1973            9                13267.00
# 1974-01-01        1974           13                 3908.00
# 1975-01-01        1975           45                97611.73

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))


years = mdates.YearLocator(5)   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

# plotting bar chart of number of claims by year
nfip_claims_year['claimscount'].plot(ax=ax, color='b', legend=False, rot=45, linewidth=4)
plt.xlabel("Year of Loss", labelpad=14)
plt.ylabel("Claims Count", labelpad=14)
plt.title("Number of NFIP Claims by Year of Loss", pad=16, fontsize=20)

# format the ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)

plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-year-count.png')

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))


years = mdates.YearLocator(5)   # every 5 year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

# plotting bar chart of number of claims by year
nfip_claims_year['amountpaidontotalclaim'].plot(ax=ax, color='b', legend=False, rot=45, linewidth=4)
plt.xlabel("Year of Loss", labelpad=14)
plt.ylabel("Amount Paid on Total Claim", labelpad=14)
plt.title("Amount Paid on Total NFIP Claims by Year of Loss", pad=16, fontsize=20)

# format the ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)

plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-year-amount.png')

# %%
sns.set(font_scale=1)
fig = pl.figure(figsize=(22,10))

# adding first subplot
ax = fig.add_subplot(121)

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))


years = mdates.YearLocator(5)   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

# plotting bar chart of number of claims by year
nfip_claims_year['claimscount'].plot(ax=ax, color='b', legend=False, rot=45, linewidth=4)
plt.xlabel("Year of Loss", labelpad=14)
plt.ylabel("Claims Count", labelpad=14)
plt.title("Number of NFIP Claims by Year of Loss", pad=16, fontsize=20)

# format the ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)

# adding second subplot
ax = fig.add_subplot(122)

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))


years = mdates.YearLocator(5)   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

# plotting bar chart of number of claims by year
nfip_claims_year['amountpaidontotalclaim'].plot(ax=ax, color='b', legend=False, rot=45, linewidth=4)
plt.xlabel("Year of Loss", labelpad=14)
plt.ylabel("Amount Paid on Total Claim", labelpad=14)
plt.title("Amount Paid on Total NFIP Claims by Year of Loss", pad=16, fontsize=20)

# format the ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)

plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-year-subplots.png')

# %%
nfip_claims_year.sort_values(by='claimscount', ascending=False).head(10)
# Out:
#             yearofloss  claimscount  amountpaidontotalclaim
# yearofloss
# 2005-01-01        2005       277024            1.428216e+10
# 2012-01-01        2012       175789            5.917678e+09
# 2017-01-01        2017       145466            9.134276e+09
# 2008-01-01        2008        96972            2.601392e+09
# 2011-01-01        2011        96461            1.524503e+09
# 1979-01-01        1979        87375            3.833123e+08
# 2016-01-01        2016        85463            2.877588e+09
# 1998-01-01        1998        83621            6.519203e+08
# 1995-01-01        1995        79582            9.605043e+08
# 2004-01-01        2004        76033            1.577862e+09

# %%
nfip_claims_year.sort_values(by='amountpaidontotalclaim', ascending=False).head(10)
# Out:
#             yearofloss  claimscount  amountpaidontotalclaim
# yearofloss
# 2005-01-01        2005       277024            1.428216e+10
# 2017-01-01        2017       145466            9.134276e+09
# 2012-01-01        2012       175789            5.917678e+09
# 2016-01-01        2016        85463            2.877588e+09
# 2008-01-01        2008        96972            2.601392e+09
# 2004-01-01        2004        76033            1.577862e+09
# 2011-01-01        2011        96461            1.524503e+09
# 2018-01-01        2018        42429            1.114654e+09
# 2001-01-01        2001        54492            1.016633e+09
# 1995-01-01        1995        79582            9.605043e+08

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

nfip_claims_year.sort_values(by='claimscount', ascending=False).head(10).plot.bar(x='yearofloss', y='claimscount', ax=ax, rot=0, color='b', fontsize=15, legend=False)
plt.xlabel("Year of Loss", labelpad=14)
plt.ylabel("Claims Count", labelpad=14)
plt.title("Top 10 Number of NFIP Claims by Year of Loss", pad=16, fontsize=20)
plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-year-count-top10.png')

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

nfip_claims_year.sort_values(by='amountpaidontotalclaim', ascending=False).head(10).plot.bar(x='yearofloss', y='amountpaidontotalclaim', ax=ax, rot=0, color='b', fontsize=15, legend=False)
plt.xlabel("Year of Loss", labelpad=14)
plt.ylabel("Amount Paid on Total Claim", labelpad=14)
plt.title("Top 10 Amount Paid on Total NFIP Claims by Year of Loss", pad=16, fontsize=20)
plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-year-amount-top10.png')

# %% [markdown]
# ## Analyzing NFIP Claims by State

# %% [markdown]
# ### Group by Claims Count

# %%
# grouping dataframe by 'Year' and summing values of columns
nfip_claims_state_count = nfip_claims.groupby('state').count()

# %%
nfip_claims_state_count.head()
# Out:
#        agriculturestructureindicator  asofdate  basefloodelevation  \
# state
# AK                                 9       666                 161
# AL                               523     40599               14269
# AR                               971      9523                1003
# AS                                 3        10                   0
# AZ                               164      4946                 365
#
#        basementenclosurecrawlspacetype  reportedcity  condominiumindicator  \
# state
# AK                                 666           664                   657
# AL                               40599         40492                 40222
# AR                                9523          9490                  9229
# AS                                  10            10                    10
# AZ                                4946          4929                  4603
#
#        policycount  countycode  crsdiscount  dateofloss  \
# state
# AK             666         660          666         666
# AL           40599       40584        40599       40599
# AR            9523        9521         9523        9523
# AS              10           9           10          10
# AZ            4946        4930         4946        4946
#
#                 ...            amountpaidonincreasedcostofcomplianceclaim  \
# state           ...
# AK              ...                                                   260
# AL              ...                                                 20851
# AR              ...                                                  4670
# AS              ...                                                     2
# AZ              ...                                                  1109
#
#        postfirmconstructionindicator  ratemethod  \
# state
# AK                               642         658
# AL                             40087       40193
# AR                              9186        9204
# AS                                 5          10
# AZ                              4614        4607
#
#        smallbusinessindicatorbuilding  totalbuildinginsurancecoverage  \
# state
# AK                                 18                             666
# AL                                775                           40599
# AR                               1396                            9523
# AS                                  3                              10
# AZ                                279                            4946
#
#        totalcontentsinsurancecoverage  yearofloss  reportedzipcode  \
# state
# AK                                666         666              664
# AL                              40599       40599            40585
# AR                               9523        9523             9521
# AS                                 10          10               10
# AZ                               4946        4946             4943
#
#        primaryresidence  amountpaidontotalclaim
# state
# AK                  375                     373
# AL                22425                   29416
# AR                 5909                    4700
# AS                    8                       6
# AZ                 1737                    2651
#
# [5 rows x 39 columns]

# %%
nfip_claims_state_count = nfip_claims_state_count[['asofdate']]

# %%
nfip_claims_state_count.head()
# Out:
#        asofdate
# state
# AK          666
# AL        40599
# AR         9523
# AS           10
# AZ         4946

# %%
nfip_claims_state_count.rename(columns={"asofdate": "claimscount"}, inplace=True)
nfip_claims_state_count.head()
# Out:
#        claimscount
# state
# AK             666
# AL           40599
# AR            9523
# AS              10
# AZ            4946

# %% [markdown]
# ### Group by Claims Amount

# %%
# grouping dataframe by 'Year' and summing values of columns
nfip_claims_state_amount = nfip_claims.groupby('state').sum()

# %%
nfip_claims_state_amount.head()
# Out:
#        basefloodelevation  basementenclosurecrawlspacetype  policycount  \
# state
# AK                44248.1                            426.0        666.0
# AL               494187.0                          11355.0      71655.0
# AR               323663.3                           3072.0       9573.0
# AS                    0.0                              0.0         10.0
# AZ               541648.9                           1212.0       5038.0
#
#        countycode  crsdiscount  elevationdifference   censustract   latitude  \
# state
# AK      1400886.0         5.45             453777.0  1.339775e+12    39960.0
# AL     42719338.0      1111.50           23409931.0  4.094744e+13  1210566.0
# AR     48369911.0        81.95            8216244.0  4.724463e+13   325975.7
# AS       540450.0         0.00               9990.0  5.404500e+11     -128.7
# AZ     19793438.0       178.50            4524232.0  1.913964e+13   159932.1
#
#           longitude  lowestadjacentgrade  lowestfloorelevation  \
# state
# AK    -9.520680e+04              33220.2               43026.7
# AL    -3.425905e+06             328303.9              666758.4
# AR    -8.558871e+05             314951.6              496133.6
# AS    -1.536300e+03                  0.0                   0.0
# AZ    -5.344809e+05             453078.2              533497.6
#
#        numberoffloorsintheinsuredbuilding  occupancytype  \
# state
# AK                                 1224.0          894.0
# AL                                62040.0        57939.0
# AR                                13570.0        14900.0
# AS                                    5.0           20.0
# AZ                                 6846.0         7517.0
#
#        amountpaidonbuildingclaim  amountpaidoncontentsclaim  \
# state
# AK                  8.945638e+06               8.386107e+05
# AL                  8.348860e+08               1.849580e+08
# AR                  1.547217e+08               2.761008e+07
# AS                  2.467571e+04               1.141024e+04
# AZ                  4.380385e+07               8.158692e+06
#
#        amountpaidonincreasedcostofcomplianceclaim  \
# state
# AK                                       69548.00
# AL                                    12251093.49
# AR                                     2028797.87
# AS                                           0.00
# AZ                                       50000.00
#
#        totalbuildinginsurancecoverage  totalcontentsinsurancecoverage  \
# state
# AK                       8.189950e+07                    1.522620e+07
# AL                       7.941595e+09                    1.124825e+09
# AR                       7.332164e+08                    1.725738e+08
# AS                       2.099000e+05                    2.790000e+04
# AZ                       4.720032e+08                    9.819450e+07
#
#        yearofloss  amountpaidontotalclaim
# state
# AK        1332343            6.099740e+06
# AL       81120056            7.109623e+08
# AR       19061928            1.124162e+08
# AS          20089            3.608595e+04
# AZ        9862732            3.321921e+07

# %%
nfip_claims_state_amount = nfip_claims_state_amount[['amountpaidontotalclaim']]

# %%
nfip_claims_state_amount.head()
# Out:
#        amountpaidontotalclaim
# state
# AK               6.099740e+06
# AL               7.109623e+08
# AR               1.124162e+08
# AS               3.608595e+04
# AZ               3.321921e+07

# %% [markdown]
# ### Merging both dataframes (i.e. claims count and amount)

# %%
nfip_claims_state_count.reset_index(inplace=True)
nfip_claims_state_amount.reset_index(inplace=True)

# %%
# merging both data frames (count and claim amount) by borough name
nfip_claims_state = nfip_claims_state_count.merge(nfip_claims_state_amount, left_on="state", 
              right_on="state")

# %%
nfip_claims_state.head()
# Out:
#   state  claimscount  amountpaidontotalclaim
# 0    AK          666            6.099740e+06
# 1    AL        40599            7.109623e+08
# 2    AR         9523            1.124162e+08
# 3    AS           10            3.608595e+04
# 4    AZ         4946            3.321921e+07

# %%
nfip_claims_state.sort_values(by='claimscount', ascending=False).head(10)
# Out:
#    state  claimscount  amountpaidontotalclaim
# 20    LA       458785            1.528993e+10
# 46    TX       371422            1.388445e+10
# 10    FL       295451            4.137530e+09
# 33    NJ       192679            3.594193e+09
# 36    NY       169501            3.313827e+09
# 29    NC       101247            1.277994e+09
# 40    PA        73523            8.176414e+08
# 27    MS        62715            2.460968e+09
# 16    IL        51837            3.227074e+08
# 5     CA        50294            3.619649e+08

# %%
nfip_claims_state.sort_values(by='amountpaidontotalclaim', ascending=False).head(10)
# Out:
#    state  claimscount  amountpaidontotalclaim
# 20    LA       458785            1.528993e+10
# 46    TX       371422            1.388445e+10
# 10    FL       295451            4.137530e+09
# 33    NJ       192679            3.594193e+09
# 36    NY       169501            3.313827e+09
# 27    MS        62715            2.460968e+09
# 29    NC       101247            1.277994e+09
# 40    PA        73523            8.176414e+08
# 1     AL        40599            7.109623e+08
# 43    SC        45728            6.147902e+08

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

nfip_claims_state.sort_values(by='claimscount', ascending=False).plot.bar(x='state', y='claimscount', ax=ax, rot=0, color='b', fontsize=15, legend=False)
plt.xlabel("State", labelpad=14)
plt.ylabel("Claims Count", labelpad=14)
plt.title("Number of NFIP Claims by State", pad=16, fontsize=20)
plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-state-count.png')

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

nfip_claims_state.sort_values(by='claimscount', ascending=False).head(10).plot.bar(x='state', y='claimscount', ax=ax, rot=0, color='b', fontsize=15, legend=False)
plt.xlabel("State", labelpad=14)
plt.ylabel("Claims Count", labelpad=14)
plt.title("Top 10 Number of NFIP Claims by State", pad=16, fontsize=20)
plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-state-count-top10.png')

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

nfip_claims_state.sort_values(by='amountpaidontotalclaim', ascending=False).plot.bar(x='state', y='amountpaidontotalclaim', ax=ax, rot=0, color='b', fontsize=15, legend=False)
plt.xlabel("State", labelpad=14)
plt.ylabel("Amount Paid on Total Claim", labelpad=14)
plt.title("Amount Paid on Total NFIP Claims by State", pad=16, fontsize=20)
plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-state-amount.png')

# %%
# defining our plot
sns.set(font_scale=1.4)
plt.subplots(figsize=(20,15))
ax = plt.subplot()

# formatting Y axis with comma
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

nfip_claims_state.sort_values(by='amountpaidontotalclaim', ascending=False).head(10).plot.bar(x='state', y='amountpaidontotalclaim', ax=ax, rot=0, color='b', fontsize=15, legend=False)
plt.xlabel("State", labelpad=14)
plt.ylabel("Amount Paid on Total Claim", labelpad=14)
plt.title("Top 10 Amount Paid on Total NFIP Claims by State", pad=16, fontsize=20)
plt.tight_layout()

#saving figure
plt.savefig('figures/nfip-claims-by-state-amount-top10.png')
